# %% [markdown]
# # Classifying dogs that look like wolfs with deep learning
#
# *by: Daniel using fastai [lesson2-download.ipynb](https://github.com/fastai/course-v3/blob/master/nbs/dl1/lesson2-download.ipynb)

# %% [markdown]
# ## Imports

# %%
import fastai

# %%
fastai.__version__
# Out:
# '1.0.59'

# %%
from fastai.vision import *

# %%
fastai.vision.__version__
# Out:
# '1.0.59'

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. Before running the following commands, you may want to disable ad blocking extensions (uBlock, AdBlockPlus etc.) in Chrome. Otherwise the window.open() command doesn't work. Then you can run the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to create different labels.

# %%
folder = 'canis_lupus_lupus'
file = 'urls_canislupus.csv'

# %%
folder = 'siberian_husky'
file = 'urls_husky.csv'

# %%
folder = 'east_siberian_laika'
file = 'urls_laika.csv'

# %%
folder = 'saarloos_wolfdog'
file = 'urls_saarloos.csv'

# %% [markdown]
# You will need to run this cell once per each category.

# %%
path = Path('data/canines')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download your images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename as well as the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['canis_lupus_lupus','siberian_husky','east_siberian_laika', 'saarloos_wolfdog']

# %%
download_images(path/file, dest, max_pics=200)

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
download_images(path/file, dest, max_pics=20, max_workers=0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-73-90f92a041deb> in <module>
#       1 # If you have problems download, try with `max_workers=0` to see exceptions:
# ----> 2 download_images(path/file, dest, max_pics=20, max_workers=0)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/fastai/vision/data.py in download_images(urls, dest, max_pics, max_workers, timeout)
#     194 def download_images(urls:Collection[str], dest:PathOrStr, max_pics:int=1000, max_workers:int=8, timeout=4):
#     195     "Download images listed in text file `urls` to path `dest`, at most `max_pics`"
# --> 196     urls = open(urls).read().strip().split("\n")[:max_pics]
#     197     dest = Path(dest)
#     198     dest.mkdir(exist_ok=True)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/canines/urls_laika.csv'

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)

# %% [markdown]
# ## View data

# %%
path
# Out:
# PosixPath('data/canines')

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['canis_lupus_lupus',
#  'east_siberian_laika',
#  'saarloos_wolfdog',
#  'siberian_husky']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['canis_lupus_lupus',
#   'east_siberian_laika',
#   'saarloos_wolfdog',
#   'siberian_husky'],
#  4,
#  584,
#  146)

# %% [markdown]
# ## Train model resnet34

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.345762</td>
#       <td>0.696075</td>
#       <td>0.297297</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.958283</td>
#       <td>0.594355</td>
#       <td>0.256757</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.738623</td>
#       <td>0.610016</td>
#       <td>0.243243</td>
#       <td>00:05</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.637513</td>
#       <td>0.613935</td>
#       <td>0.236486</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
# If the plot is not showing try to give a start and end learning rate
# learn.lr_find(start_lr=1e-5, end_lr=1e-1)
learn.recorder.plot()

# %% [markdown]
# Retrain using new learning rate

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.363093</td>
#       <td>0.637683</td>
#       <td>0.222973</td>
#       <td>00:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.311576</td>
#       <td>0.627191</td>
#       <td>0.202703</td>
#       <td>00:05</td>
#     </tr>
#   </tbody>
# </table>

# %%
# end learning rate usually 3e-4, start learning rate when slope is the steepest and longest

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.most_confused(min_val=2)
# Out:
# [('east_siberian_laika', 'saarloos_wolfdog', 6),
#  ('saarloos_wolfdog', 'canis_lupus_lupus', 6),
#  ('saarloos_wolfdog', 'east_siberian_laika', 6),
#  ('east_siberian_laika', 'siberian_husky', 3),
#  ('siberian_husky', 'east_siberian_laika', 3),
#  ('canis_lupus_lupus', 'saarloos_wolfdog', 2),
#  ('saarloos_wolfdog', 'siberian_husky', 2)]

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `ImageCleaner` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.

# %%
from fastai.widgets import *

# %% [markdown]
# First we need to get the file paths from our top_losses. We can do this with `.from_toplosses`. We then feed the top losses indexes and corresponding dataset to `ImageCleaner`.
#
# Notice that the widget will not delete images directly from disk but it will create a new csv file `cleaned.csv` from where you can create a new ImageDataBunch with the corrected labels to continue training your model.

# %% [markdown]
# In order to clean the entire set of images, we need to create a new dataset without the split. The video lecture demostrated the use of the `ds_type` param which no longer has any effect. See [the thread](https://forums.fast.ai/t/duplicate-widget/30975/10) for more details.

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

db_cln = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
                   .split_none()
                   .label_from_df()
                   .transform(get_transforms(), size=224)
                    .databunch()
      )

# %%
np.random.seed(42)
db_rm_dup = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
                   .split_none()
                   .label_from_df()
                   .transform(get_transforms(), size=224)
                    .databunch()
      )

# %%
# Problem was databunch did not specify traintest split
db_rm_dup.classes, db_rm_dup.c, len(db_rm_dup.train_ds), len(db_rm_dup.valid_ds)
# Out:
# (['canis_lupus_lupus',
#   'east_siberian_laika',
#   'saarloos_wolfdog',
#   'siberian_husky'],
#  4,
#  639,
#  1)

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
learn_frm_cln = cnn_learner(db_cln, models.resnet34, metrics=error_rate)

learn_frm_cln.load('stage-2');

# %%
# learner after removing duplicates
learn_dup = cnn_learner(db_rm_dup, models.resnet34, metrics=error_rate)

learn_dup.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
# Don't run this in google colab or any other instances running jupyter lab.
# If you do run this on Jupyter Lab, you need to restart your runtime and
# runtime state including all local variables will be lost.
ImageCleaner(ds, idxs, path)
# Out:
# 'No images to show :)'

# %% [markdown]
# If the code above does not show any GUI(contains images and buttons) rendered by widgets but only text output, that may caused by the configuration problem of ipywidgets. Try the solution in this [link](https://github.com/fastai/fastai/issues/1539#issuecomment-505999861) to solve it.

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Next Batch' to delete flagged photos and keep the rest in that row. `ImageCleaner` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses.ImageCleaner(ds, idxs)`

# %% [markdown]
# You can also find duplicates in your dataset and delete them! To do this, you need to run `.from_similars` to get the potential duplicates' ids and then run `ImageCleaner` with `duplicates=True`. The API works in a similar way as with misclassified images: just choose the ones you want to delete and click 'Next Batch' until there are no more images left.

# %% [markdown]
# Make sure to recreate the databunch and `learn_cln` from the `cleaned.csv` file. Otherwise the file would be overwritten from scratch, losing all the results from cleaning the data from toplosses.

# %%
ds, idxs = DatasetFormatter().from_similars(learn_frm_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11' class='' max='11', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11/11 00:02<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %% [markdown]
# ## Putting your model in production

# %% [markdown]
# First thing first, let's export the content of our `Learner` object for production:

# %%
learn_frm_cln.export()

# %% [markdown]
# This will create a file named 'export.pkl' in the directory where we were working that contains everything we need to deploy our model (the model, the weights but also some metadata like the classes or the transforms/normalization used).

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
defaults.device = torch.device('cpu')

# %%
img = open_image(path/'canis_lupus_lupus'/'00000055.jpg')
img
# Out:
# Image (3, 333, 500)

# %% [markdown]
# We create our `Learner` in production enviromnent like this, just make sure that `path` contains the file 'export.pkl' from before.

# %%
path.ls()
# Out:
# [PosixPath('data/canines/canis_lupus_lupus'),
#  PosixPath('data/canines/export.pkl'),
#  PosixPath('data/canines/urls_canislupus.csv'),
#  PosixPath('data/canines/urls_laika.csv'),
#  PosixPath('data/canines/urls_saarloos.csv'),
#  PosixPath('data/canines/models'),
#  PosixPath('data/canines/urls_husky.csv'),
#  PosixPath('data/canines/siberian_husky'),
#  PosixPath('data/canines/east_siberian_laika'),
#  PosixPath('data/canines/saarloos_wolfdog'),
#  PosixPath('data/canines/cleaned.csv')]

# %%
doc(load_learner)

# %%
learn = load_learner(path, 'export.pkl')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# Category canis_lupus_lupus

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Create new learner with cleaned data

# %%
# Recreate databunch from cleaned data
data2 = ImageDataBunch.from_csv(path,csv_labels='cleaned.csv',label_col=1,
                        valid_pct=0.2,ds_tfms=get_transforms(), 
                        size=224, num_workers=0).normalize(imagenet_stats)

# %%
data2.classes, data2.c, len(data2.train_ds), len(data2.valid_ds)
# Out:
# (['canis_lupus_lupus',
#   'east_siberian_laika',
#   'saarloos_wolfdog',
#   'siberian_husky'],
#  4,
#  512,
#  127)

# %%
learn2 = cnn_learner(data2, models.resnet34, metrics=error_rate)

# %%
learn2.fit_one_cycle(4)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.319113</td>
#       <td>0.591067</td>
#       <td>0.212598</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.979524</td>
#       <td>0.488869</td>
#       <td>0.141732</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.776162</td>
#       <td>0.493462</td>
#       <td>0.133858</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.658641</td>
#       <td>0.469837</td>
#       <td>0.125984</td>
#       <td>00:13</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.save('stage_1cln')

# %%
interp = ClassificationInterpretation.from_learner(learn2)

losses,idxs = interp.top_losses()

len(data2.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15, 11))

# %% [markdown]
# Previously our first model is most confused with these:
# ('east_siberian_laika', 'saarloos_wolfdog', 6),
#  ('saarloos_wolfdog', 'canis_lupus_lupus', 6),
#  ('saarloos_wolfdog', 'east_siberian_laika', 6),
#  ('east_siberian_laika', 'siberian_husky', 3),
#  ('siberian_husky', 'east_siberian_laika', 3),
#  ('canis_lupus_lupus', 'saarloos_wolfdog', 2),
#  ('saarloos_wolfdog', 'siberian_husky', 2)

# %% [markdown]
# Actual, predicted, number of times of incorrect classification

# %%
interp.most_confused(min_val=2)
# Out:
# [('saarloos_wolfdog', 'east_siberian_laika', 6),
#  ('saarloos_wolfdog', 'canis_lupus_lupus', 4),
#  ('canis_lupus_lupus', 'saarloos_wolfdog', 2),
#  ('siberian_husky', 'east_siberian_laika', 2)]

# %% [markdown]
# Now our model has less misclassification with the new data.

# %%
learn2.unfreeze()

# %%
learn2.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.534806</td>
#       <td>0.777145</td>
#       <td>0.267717</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.load('stage_1cln');

# %%
learn2.lr_find()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn2.recorder.plot()

# %%
learn2.unfreeze()
learn2.fit_one_cycle(2, max_lr=slice(1e-4, 3e-4))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.370229</td>
#       <td>0.530779</td>
#       <td>0.173228</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.294393</td>
#       <td>0.420939</td>
#       <td>0.133858</td>
#       <td>00:14</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn2.save('stage_2cln')

# %% [markdown]
# ## Resnet-50

# %%
learn_50 = cnn_learner(data2, models.resnet50, metrics=error_rate)

# %%
learn_50.fit_one_cycle(8)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.263684</td>
#       <td>0.589205</td>
#       <td>0.204724</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.881694</td>
#       <td>0.388366</td>
#       <td>0.118110</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.674514</td>
#       <td>0.374491</td>
#       <td>0.110236</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.542605</td>
#       <td>0.351605</td>
#       <td>0.102362</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.450879</td>
#       <td>0.323534</td>
#       <td>0.102362</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
interp_50 = ClassificationInterpretation.from_learner(learn_50)

losses,idxs = interp_50.top_losses()

len(data2.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp_50.plot_top_losses(9, figsize=(15,11))

# %%
# Different from what resnet34 is most confused with
interp_50.most_confused(min_val=2)
# Out:
# [('saarloos_wolfdog', 'canis_lupus_lupus', 5),
#  ('canis_lupus_lupus', 'saarloos_wolfdog', 3)]

# %% [markdown]
# Using resnet50, we only have two classes that have more than 2 misclassifications

# %%
learn_50.lr_find()
learn_50.recorder.plot()
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn_50.save('stage-1-50')
